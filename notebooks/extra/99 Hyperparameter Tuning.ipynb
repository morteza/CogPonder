# %% [markdown]
# # CogPonder: An Interoperable Model of Response Times in Cognitive Tasks
#
# We are interested in a model of response time that is interoperable in human data and computational agents.
#
# Inspired by [PonderNet](https://arxiv.org/abs/2107.05407), this notebook demonstrates CogPonder, a differentiable model that produces human-like speed-accuracy in decision making tasks.
#
# The model iterates over a recurrent decision network, terminating only when it reaches a halting step. The network is trained to 1) maximize decision accuracy and 2) maximize the similarity between the human response time distribution and the halting steps of the network.
#
#
# ## Tasks
#
# ### N-back Task
#
# N-back is a cognitive test commonly used to tap into working memory. In this task, human subjects are presented with a sequence of symbols, and are asked to respond with the "target" button whe the current symbol matches the one from N steps earlier in the sequence. The load factor N can be adjusted the difficulty of the task.
#
# Here, we use a 2-back dataset from [Self-Regulation Ontology study]() to evaluate the architecture. The mock dataset includes, for each subject, trial-level $X$ (symbol), $is_targets$ (or $y$; whether it was a target), $responses$, and $response\_times$.
#
#
# The dataset interface provides the following features:
#
# - $X_i$: previous 3 symbols for the trial i; $X_i$ is a 3-dimensional vector of integers.
# - $\text{trial\_type}_i$: see the "Trial types" section below.
# - $\text{is\_target}_i$: whether the trial i is a match; $is\_targets_i$ is a boolean.
# - $\text{response}_i$: the response of the subject for the trial i; $responses_i$ is a boolean.
# - $\text{response\_step}_i$: the response step of the subject for the trial i; $response\_times_i$ is a float. Response steps represent RT in 50ms steps.
#
# #### Trial types
#
# The  dataset includes 3 trial types depending on the response and whether the symbols was a target:
#
# 1. correct match
# 2. correct non-match
# 3. incorrect match
# 4. incorrect non-match
#
#
# ### Decision Model
#
# We want to learn a supervised approximation of the $X \to y$ as follows:
# $
# f: X,h_n \mapsto \tilde{y},h_{n+1}, \lambda_n
# $
#
# where $X$ and $y$ denote recent stimulus and responses, $\lambda_n$ is the halting probability at step $n$, and $h_{n}$ is the latent state of the decision model. The learning process continues for a maximum of $N_{max}$ steps. The duration of each step is in fact a hyperparameter of the model, but for brevity is considered 100ms. ($\lambda_n$) is the halting probability in step $n$ (given a Bernoulli distribution), and $p_n$ is the probability of halting at step $n$, which imply that in all the previous steps it did not halt. The halting probability is a function of the latent state $h_n$, $lambda_n$, and the current symbol $X$.
#
# For the N-back task, we define X as a moving window of recent N+1 symbols, e.g., [A, B, C] and [B, C, D], ...; and $y$ is either NON_MATCH (False or 0) or MATCH (True or 1).
#
# ### Output
#
# The *CogPonder* network outputs $y\_steps$, $p\_halts$, $halt\_steps$ for each item in the batch. Batch items represent the trials in the N-back task.
#
# ### Criterion
#
# $L = L_{\text{reconstruction}} + L_{\text{cognitive}}$

# %%
# %reload_ext autoreload
# %autoreload 3

import torch
import torch.nn.functional as F
import pytorch_lightning as pl
from ray import tune, air
from ray.tune import JupyterNotebookReporter
from functools import partial
from pytorch_lightning.callbacks import RichProgressBar, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger
from ray.tune.integration.pytorch_lightning import TuneReportCallback
from cogponder import CogPonderModel
from cogponder.datasets import NBackMockDataset, CogPonderDataModule, NBackSRODataset
from pathlib import Path

# CONSTANTS
import os
os.environ['RAY_PICKLE_VERBOSE_DEBUG'] = '1'

# %%
# load the data
# mock_data = NBackMockDataset(n_subjects=1, n_trials=198, n_stimuli=5, n_back=2)

# create data module for handling data in PyTorch Lightning

# %%
def train_tune(config, epochs=10, data_file=None):

    data = NBackSRODataset(n_subjects=1, n_back=2, data_file=data_file) # shape (n_subjects, (...))
    datamodule = NBackDataModule(data, batch_size=8)
    n_symbols = torch.unique(data[0][0]).shape[0]
    max_response_step = data[0][4].max() + 10
    lambda_p = 1. / data[0][4].median()

    max_response_step = max_response_step.item()
    lambda_p = lambda_p.item()

    config['max_response_step'] = max_response_step
    config['lambda_p'] = lambda_p
    config['n_symbols'] = n_symbols
    config['embeddings_dim'] = n_symbols

    # decision_model = ICOM(n_inputs=n_symbols+1, n_embeddings=n_symbols, n_outputs=2)

    # pondering model
    model = CogPonderModel(
        config,
        example_input_array=data[0][0][:2])

    trainer = pl.Trainer(
        logger=TensorBoardLogger(save_dir=os.getcwd(), name='', version='.'),
        max_epochs=epochs,
        log_every_n_steps=8,
        enable_progress_bar=False,
        # auto_scale_batch_size=True,
        callbacks=[
            TuneReportCallback(['val_loss'], on='validation_end'),
            # RichProgressBar(),
            EarlyStopping(monitor='val_loss', patience=25, mode='min', min_delta=0.01),
        ])

    trainer.fit(model, datamodule=datamodule)

# parameters to tune
config = {
    'loss_beta': .5,
    'loss_by_trial_type': False,
    'learning_rate': 1e-4,
}

# WORKAROUND for PTL 1.7 and RayTune
# See https://github.com/ray-project/ray/issues/28197
import ray
ray.shutdown()
ray.init(runtime_env={"env_vars": {"PL_DISABLE_FORK": "1"}})

# hyperparameter tuner
tuner = tune.Tuner(
    trainable=partial(
        train_tune,
        epochs=100,
        data_file='~/workspace/CogPonder/data/Self_Regulation_Ontology/adaptive_n_back.csv.gz'),
    tune_config=tune.TuneConfig(
        metric='val_loss',
        mode='min',
        num_samples=1,
    ),
    run_config=air.RunConfig(
            log_to_file=True,
            verbose=0,
            progress_reporter = JupyterNotebookReporter(
                parameter_columns=['loss_beta'],
                metric_columns=['val_loss']),
        ),
    param_space=config,
)

# run the tuner
results = tuner.fit()
# Out:
# == Status ==<br>Current time: 2022-10-04 16:32:07 (running for 00:07:26.20)<br>Memory usage on this node: 9.2/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/0 GPUs, 0.0/5.68 GiB heap, 0.0/2.0 GiB objects<br>Current best trial: 48d14_00000 with val_loss=0.6956002116203308 and parameters={'loss_beta': 0.5}<br>Result logdir: /Users/morteza/ray_results/train_tune_2022-10-04_16-24-41<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  loss_beta</th><th style="text-align: right;">  val_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>train_tune_48d14_00000</td><td>TERMINATED</td><td>127.0.0.1:64765</td><td style="text-align: right;">        0.5</td><td style="text-align: right;">    0.6956</td></tr>
# </tbody>
# </table><br><br>
# (raylet) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/ray/dashboard/agent.py:50: DeprecationWarning: There is no current event loop
# (raylet)   aiogrpc.init_grpc_aio()
# (raylet) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/ray/dashboard/agent.py:470: DeprecationWarning: There is no current event loop
# (raylet)   loop = asyncio.get_event_loop()
# (func pid=64765) GPU available: False, used: False
# (func pid=64765) TPU available: False, using: 0 TPU cores
# (func pid=64765) IPU available: False, using: 0 IPUs
# (func pid=64765) HPU available: False, using: 0 HPUs
# (func pid=64765) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:229: LightningDeprecationWarning: The `on_init_start` callback hook was deprecated in v1.6 and will be removed in v1.8.
# (func pid=64765)   rank_zero_deprecation(
# (func pid=64765) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:233: LightningDeprecationWarning: The `on_init_end` callback hook was deprecated in v1.6 and will be removed in v1.8.
# (func pid=64765)   rank_zero_deprecation("The `on_init_end` callback hook was deprecated in v1.6 and will be removed in v1.8.")
# (func pid=64765) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:258: LightningDeprecationWarning: The `Callback.on_batch_start` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_train_batch_start` instead.
# (func pid=64765)   rank_zero_deprecation(
# (func pid=64765) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:258: LightningDeprecationWarning: The `Callback.on_batch_end` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_train_batch_end` instead.
# (func pid=64765)   rank_zero_deprecation(
# (func pid=64765) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:267: LightningDeprecationWarning: The `Callback.on_epoch_start` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_<train/validation/test>_epoch_start` instead.
# (func pid=64765)   rank_zero_deprecation(
# (func pid=64765) /usr/local/Caskroom/miniforge/base/envs/ponder/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:267: LightningDeprecationWarning: The `Callback.on_epoch_end` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_<train/validation/test>_epoch_end` instead.
# (func pid=64765)   rank_zero_deprecation(
# (func pid=64765)
# (func pid=64765)   | Name           | Type       | Params | In sizes            | Out sizes
# (func pid=64765) ------------------------------------------------------------------------------------------
# (func pid=64765) 0 | decision_model | ICOM       | 100    | [[2, 3], [1, 2, 5]] | [[2, 2], [1, 2, 5]]
# (func pid=64765) 1 | halt_node      | Sequential | 7      | [1, 2, 6]           | [1, 2, 1]
# (func pid=64765) ------------------------------------------------------------------------------------------
# (func pid=64765) 107       Trainable params
# (func pid=64765) 0         Non-trainable params
# (func pid=64765) 107       Total params
# (func pid=64765) 0.000     Total estimated model params size (MB)
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-00
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 12.50996994972229
#   time_this_iter_s: 12.50996994972229
#   time_total_s: 12.50996994972229
#   timestamp: 1664893500
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 48d14_00000
#   val_loss: 0.7188934087753296
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-07
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 2
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 19.746084690093994
#   time_this_iter_s: 7.236114740371704
#   time_total_s: 19.746084690093994
#   timestamp: 1664893507
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 48d14_00000
#   val_loss: 0.7180671691894531
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-15
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 3
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 27.788437843322754
#   time_this_iter_s: 8.04235315322876
#   time_total_s: 27.788437843322754
#   timestamp: 1664893515
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 48d14_00000
#   val_loss: 0.7172481417655945
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-23
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 4
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 35.095027923583984
#   time_this_iter_s: 7.3065900802612305
#   time_total_s: 35.095027923583984
#   timestamp: 1664893523
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 48d14_00000
#   val_loss: 0.7164353132247925
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-31
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 5
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 43.60561466217041
#   time_this_iter_s: 8.510586738586426
#   time_total_s: 43.60561466217041
#   timestamp: 1664893531
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: 48d14_00000
#   val_loss: 0.7156288027763367
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-40
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 6
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 52.23505091667175
#   time_this_iter_s: 8.629436254501343
#   time_total_s: 52.23505091667175
#   timestamp: 1664893540
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 48d14_00000
#   val_loss: 0.7148314714431763
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-48
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 7
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 60.7097909450531
#   time_this_iter_s: 8.474740028381348
#   time_total_s: 60.7097909450531
#   timestamp: 1664893548
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: 48d14_00000
#   val_loss: 0.7060425281524658
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-25-57
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 8
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 68.99810671806335
#   time_this_iter_s: 8.288315773010254
#   time_total_s: 68.99810671806335
#   timestamp: 1664893557
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: 48d14_00000
#   val_loss: 0.7132623791694641
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-04
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 9
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 76.94686484336853
#   time_this_iter_s: 7.948758125305176
#   time_total_s: 76.94686484336853
#   timestamp: 1664893564
#   timesteps_since_restore: 0
#   training_iteration: 9
#   trial_id: 48d14_00000
#   val_loss: 0.708490788936615
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-13
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 10
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 85.28090596199036
#   time_this_iter_s: 8.334041118621826
#   time_total_s: 85.28090596199036
#   timestamp: 1664893573
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 48d14_00000
#   val_loss: 0.7117325663566589
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-22
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 11
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 93.98662972450256
#   time_this_iter_s: 8.705723762512207
#   time_total_s: 93.98662972450256
#   timestamp: 1664893582
#   timesteps_since_restore: 0
#   training_iteration: 11
#   trial_id: 48d14_00000
#   val_loss: 0.7109827995300293
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-29
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 12
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 101.72039675712585
#   time_this_iter_s: 7.733767032623291
#   time_total_s: 101.72039675712585
#   timestamp: 1664893589
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 48d14_00000
#   val_loss: 0.7102459669113159
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-37
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 13
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 109.22328186035156
#   time_this_iter_s: 7.502885103225708
#   time_total_s: 109.22328186035156
#   timestamp: 1664893597
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: 48d14_00000
#   val_loss: 0.701522707939148
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-45
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 14
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 117.12222695350647
#   time_this_iter_s: 7.898945093154907
#   time_total_s: 117.12222695350647
#   timestamp: 1664893605
#   timesteps_since_restore: 0
#   training_iteration: 14
#   trial_id: 48d14_00000
#   val_loss: 0.7088111639022827
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-26-53
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 15
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 125.29067897796631
#   time_this_iter_s: 8.168452024459839
#   time_total_s: 125.29067897796631
#   timestamp: 1664893613
#   timesteps_since_restore: 0
#   training_iteration: 15
#   trial_id: 48d14_00000
#   val_loss: 0.7081171870231628
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-01
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 16
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 133.60156178474426
#   time_this_iter_s: 8.310882806777954
#   time_total_s: 133.60156178474426
#   timestamp: 1664893621
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 48d14_00000
#   val_loss: 0.7034333348274231
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-09
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 17
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 141.56712293624878
#   time_this_iter_s: 7.965561151504517
#   time_total_s: 141.56712293624878
#   timestamp: 1664893629
#   timesteps_since_restore: 0
#   training_iteration: 17
#   trial_id: 48d14_00000
#   val_loss: 0.7027682662010193
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-18
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 18
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 150.5097427368164
#   time_this_iter_s: 8.942619800567627
#   time_total_s: 150.5097427368164
#   timestamp: 1664893638
#   timesteps_since_restore: 0
#   training_iteration: 18
#   trial_id: 48d14_00000
#   val_loss: 0.7061188220977783
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-27
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 19
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 159.8042688369751
#   time_this_iter_s: 9.294526100158691
#   time_total_s: 159.8042688369751
#   timestamp: 1664893647
#   timesteps_since_restore: 0
#   training_iteration: 19
#   trial_id: 48d14_00000
#   val_loss: 0.7054864168167114
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-37
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 169.6845760345459
#   time_this_iter_s: 9.8803071975708
#   time_total_s: 169.6845760345459
#   timestamp: 1664893657
#   timesteps_since_restore: 0
#   training_iteration: 20
#   trial_id: 48d14_00000
#   val_loss: 0.7048726081848145
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-47
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 21
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 179.50663495063782
#   time_this_iter_s: 9.822058916091919
#   time_total_s: 179.50663495063782
#   timestamp: 1664893667
#   timesteps_since_restore: 0
#   training_iteration: 21
#   trial_id: 48d14_00000
#   val_loss: 0.704276442527771
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-27-56
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 22
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 188.14323568344116
#   time_this_iter_s: 8.636600732803345
#   time_total_s: 188.14323568344116
#   timestamp: 1664893676
#   timesteps_since_restore: 0
#   training_iteration: 22
#   trial_id: 48d14_00000
#   val_loss: 0.6996980905532837
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-28-04
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 23
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 196.0736439228058
#   time_this_iter_s: 7.930408239364624
#   time_total_s: 196.0736439228058
#   timestamp: 1664893684
#   timesteps_since_restore: 0
#   training_iteration: 23
#   trial_id: 48d14_00000
#   val_loss: 0.6951419115066528
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-28-14
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 24
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 206.2880277633667
#   time_this_iter_s: 10.214383840560913
#   time_total_s: 206.2880277633667
#   timestamp: 1664893694
#   timesteps_since_restore: 0
#   training_iteration: 24
#   trial_id: 48d14_00000
#   val_loss: 0.7026031613349915
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-28-23
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 25
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 215.48034977912903
#   time_this_iter_s: 9.192322015762329
#   time_total_s: 215.48034977912903
#   timestamp: 1664893703
#   timesteps_since_restore: 0
#   training_iteration: 25
#   trial_id: 48d14_00000
#   val_loss: 0.7020871639251709
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-28-32
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 26
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 224.45434880256653
#   time_this_iter_s: 8.9739990234375
#   time_total_s: 224.45434880256653
#   timestamp: 1664893712
#   timesteps_since_restore: 0
#   training_iteration: 26
#   trial_id: 48d14_00000
#   val_loss: 0.7015911936759949
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-28-42
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 27
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 234.36793494224548
#   time_this_iter_s: 9.913586139678955
#   time_total_s: 234.36793494224548
#   timestamp: 1664893722
#   timesteps_since_restore: 0
#   training_iteration: 27
#   trial_id: 48d14_00000
#   val_loss: 0.701115608215332
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-28-52
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 28
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 244.75455784797668
#   time_this_iter_s: 10.386622905731201
#   time_total_s: 244.75455784797668
#   timestamp: 1664893732
#   timesteps_since_restore: 0
#   training_iteration: 28
#   trial_id: 48d14_00000
#   val_loss: 0.7006629705429077
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-29-02
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 29
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 254.5819787979126
#   time_this_iter_s: 9.827420949935913
#   time_total_s: 254.5819787979126
#   timestamp: 1664893742
#   timesteps_since_restore: 0
#   training_iteration: 29
#   trial_id: 48d14_00000
#   val_loss: 0.7002315521240234
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-29-11
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 30
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 263.6147518157959
#   time_this_iter_s: 9.0327730178833
#   time_total_s: 263.6147518157959
#   timestamp: 1664893751
#   timesteps_since_restore: 0
#   training_iteration: 30
#   trial_id: 48d14_00000
#   val_loss: 0.6998203992843628
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-29-20
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 31
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 272.6534426212311
#   time_this_iter_s: 9.03869080543518
#   time_total_s: 272.6534426212311
#   timestamp: 1664893760
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 48d14_00000
#   val_loss: 0.6914306282997131
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-29-29
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 32
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 281.07532787323
#   time_this_iter_s: 8.421885251998901
#   time_total_s: 281.07532787323
#   timestamp: 1664893769
#   timesteps_since_restore: 0
#   training_iteration: 32
#   trial_id: 48d14_00000
#   val_loss: 0.6950616240501404
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-29-39
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 33
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 291.0840229988098
#   time_this_iter_s: 10.008695125579834
#   time_total_s: 291.0840229988098
#   timestamp: 1664893779
#   timesteps_since_restore: 0
#   training_iteration: 33
#   trial_id: 48d14_00000
#   val_loss: 0.6987138986587524
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-29-50
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 34
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 302.02849984169006
#   time_this_iter_s: 10.944476842880249
#   time_total_s: 302.02849984169006
#   timestamp: 1664893790
#   timesteps_since_restore: 0
#   training_iteration: 34
#   trial_id: 48d14_00000
#   val_loss: 0.6943864822387695
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-30-08
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 35
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 320.41721773147583
#   time_this_iter_s: 18.388717889785767
#   time_total_s: 320.41721773147583
#   timestamp: 1664893808
#   timesteps_since_restore: 0
#   training_iteration: 35
#   trial_id: 48d14_00000
#   val_loss: 0.698078453540802
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-30-16
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 36
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 328.30139803886414
#   time_this_iter_s: 7.884180307388306
#   time_total_s: 328.30139803886414
#   timestamp: 1664893816
#   timesteps_since_restore: 0
#   training_iteration: 36
#   trial_id: 48d14_00000
#   val_loss: 0.6977888941764832
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-30-24
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 37
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 336.3469948768616
#   time_this_iter_s: 8.045596837997437
#   time_total_s: 336.3469948768616
#   timestamp: 1664893824
#   timesteps_since_restore: 0
#   training_iteration: 37
#   trial_id: 48d14_00000
#   val_loss: 0.6935194730758667
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-30-32
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 38
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 344.7976257801056
#   time_this_iter_s: 8.450630903244019
#   time_total_s: 344.7976257801056
#   timestamp: 1664893832
#   timesteps_since_restore: 0
#   training_iteration: 38
#   trial_id: 48d14_00000
#   val_loss: 0.6972684860229492
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-30-42
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 39
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 354.1453776359558
#   time_this_iter_s: 9.34775185585022
#   time_total_s: 354.1453776359558
#   timestamp: 1664893842
#   timesteps_since_restore: 0
#   training_iteration: 39
#   trial_id: 48d14_00000
#   val_loss: 0.6930359601974487
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-30-52
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 40
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 364.21170377731323
#   time_this_iter_s: 10.066326141357422
#   time_total_s: 364.21170377731323
#   timestamp: 1664893852
#   timesteps_since_restore: 0
#   training_iteration: 40
#   trial_id: 48d14_00000
#   val_loss: 0.6968176364898682
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-02
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 41
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 374.2142426967621
#   time_this_iter_s: 10.002538919448853
#   time_total_s: 374.2142426967621
#   timestamp: 1664893862
#   timesteps_since_restore: 0
#   training_iteration: 41
#   trial_id: 48d14_00000
#   val_loss: 0.6966174840927124
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-11
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 42
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 383.4555127620697
#   time_this_iter_s: 9.241270065307617
#   time_total_s: 383.4555127620697
#   timestamp: 1664893871
#   timesteps_since_restore: 0
#   training_iteration: 42
#   trial_id: 48d14_00000
#   val_loss: 0.6964305639266968
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-20
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 43
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 392.1887848377228
#   time_this_iter_s: 8.733272075653076
#   time_total_s: 392.1887848377228
#   timestamp: 1664893880
#   timesteps_since_restore: 0
#   training_iteration: 43
#   trial_id: 48d14_00000
#   val_loss: 0.6882613301277161
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-28
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 44
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 400.80228781700134
#   time_this_iter_s: 8.613502979278564
#   time_total_s: 400.80228781700134
#   timestamp: 1664893888
#   timesteps_since_restore: 0
#   training_iteration: 44
#   trial_id: 48d14_00000
#   val_loss: 0.6961033940315247
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-37
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 45
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 409.2044007778168
#   time_this_iter_s: 8.40211296081543
#   time_total_s: 409.2044007778168
#   timestamp: 1664893897
#   timesteps_since_restore: 0
#   training_iteration: 45
#   trial_id: 48d14_00000
#   val_loss: 0.69595867395401
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-47
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 46
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 419.3574228286743
#   time_this_iter_s: 10.153022050857544
#   time_total_s: 419.3574228286743
#   timestamp: 1664893907
#   timesteps_since_restore: 0
#   training_iteration: 46
#   trial_id: 48d14_00000
#   val_loss: 0.6958284974098206
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-31-56
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 47
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 428.91932797431946
#   time_this_iter_s: 9.561905145645142
#   time_total_s: 428.91932797431946
#   timestamp: 1664893916
#   timesteps_since_restore: 0
#   training_iteration: 47
#   trial_id: 48d14_00000
#   val_loss: 0.6957119703292847
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-32-05
#   done: false
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   hostname: MP0159
#   iterations_since_restore: 48
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 437.0388059616089
#   time_this_iter_s: 8.119477987289429
#   time_total_s: 437.0388059616089
#   timestamp: 1664893925
#   timesteps_since_restore: 0
#   training_iteration: 48
#   trial_id: 48d14_00000
#   val_loss: 0.6956002116203308
#   warmup_time: 0.004273891448974609
#
# Result for train_tune_48d14_00000:
#   date: 2022-10-04_16-32-05
#   done: true
#   experiment_id: c7051382dfc34529a0c452786854ff14
#   experiment_tag: '0'
#   hostname: MP0159
#   iterations_since_restore: 48
#   node_ip: 127.0.0.1
#   pid: 64765
#   time_since_restore: 437.0388059616089
#   time_this_iter_s: 8.119477987289429
#   time_total_s: 437.0388059616089
#   timestamp: 1664893925
#   timesteps_since_restore: 0
#   training_iteration: 48
#   trial_id: 48d14_00000
#   val_loss: 0.6956002116203308
#   warmup_time: 0.004273891448974609
# 2022-10-04 16:32:07,433	INFO tune.py:758 -- Total run time: 446.32 seconds (446.20 seconds for the tuning loop).

# %% [markdown]
# # WARNING: the remaining codes won't work with Ray-Tune.
#
# Please use previous version of the notebook from the git.

# %%
# DEBUG

import torch

X_train, _, _, _, rt_train = datamodule.dataset[datamodule.train_dataset.indices]
X_test, _, _, _, rt_test = datamodule.dataset[datamodule.test_dataset.indices]

with torch.no_grad():
    model.eval()
    rt_train_pred = model(X_train)[2].detach()
    rt_test_pred = model(X_test)[2].detach()

    # DEBUG report the ground truth and predicted response times
    print('TRUE TRAIN:', rt_train.detach().tolist(), '\nPRED TRAIN:',  rt_train_pred.tolist())
    print('TRUE TEST:', rt_test.detach().tolist(), '\nPRED TEST:',  rt_test_pred.tolist())

# DEBUG report medians
# rt_train_pred.median(), rt_train.float().median()
# rt_test_pred.median(), rt_test.float().median()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.ecdfplot(rt_train.detach(), label='True (train)')
sns.ecdfplot(rt_train_pred.detach(), label='Predicted (train)')

plt.title('Evaluation of PonderNet on simulated train split')
plt.xlabel('response time (steps)')

plt.legend()
plt.show()

sns.ecdfplot(rt_test.detach(), label='True (test)')
sns.ecdfplot(rt_test_pred.detach(), label='Predicted (test)')

plt.title('Evaluation of PonderNet on simulated test split')
plt.xlabel('response time (steps)')
plt.legend()
plt.show()

# %%
sns.kdeplot(rt_train.detach(), label='Train (TRUE)', cut=0)
sns.kdeplot(rt_train_pred.detach(), label='Train (PRED)', cut=0)

sns.kdeplot(rt_test.detach(), label='Test (TRUE)', cut=0)
sns.kdeplot(rt_test_pred.detach(), label='Test (PRED)', cut=0)


plt.title('Evaluation of PonderNet on SRO single-subject 2-back')
plt.xlabel('response time (steps)')
plt.legend()
plt.show()
